# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonjstewart/college-football/blob/master/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('https://jasonstewart.s3.amazonaws.com/shot_logs.csv')
df
#THIS IS AWESOME
# Out:
#          GAME_ID                   MATCHUP  ...    player_name player_id
# 0       21400899  MAR 04, 2015 - CHA @ BKN  ...  brian roberts    203148
# 1       21400899  MAR 04, 2015 - CHA @ BKN  ...  brian roberts    203148
# 2       21400899  MAR 04, 2015 - CHA @ BKN  ...  brian roberts    203148
# 3       21400899  MAR 04, 2015 - CHA @ BKN  ...  brian roberts    203148
# 4       21400899  MAR 04, 2015 - CHA @ BKN  ...  brian roberts    203148
# ...          ...                       ...  ...            ...       ...
# 128064  21400006  OCT 29, 2014 - BKN @ BOS  ...   jarrett jack    101127
# 128065  21400006  OCT 29, 2014 - BKN @ BOS  ...   jarrett jack    101127
# 128066  21400006  OCT 29, 2014 - BKN @ BOS  ...   jarrett jack    101127
# 128067  21400006  OCT 29, 2014 - BKN @ BOS  ...   jarrett jack    101127
# 128068  21400006  OCT 29, 2014 - BKN @ BOS  ...   jarrett jack    101127
#
# [128069 rows x 21 columns]
